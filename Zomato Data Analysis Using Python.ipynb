# %% [markdown]
# <a href="https://colab.research.google.com/github/pritibhartigithub/CalculatorinPython/blob/main/Zomato%20Data%20Analysis%20Using%20Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("ji")
# Out:
# ji
